# %%
from datasets import load_dataset
import pandas as pd
import numpy as np

# %%
#data = load_dataset("squad", split = "train")
#data = load_dataset("c4", "en", split= "train", streaming = True)
data = load_dataset("squad_v2", split = "train")
# Out:
# Reusing dataset squad_v2 (/home/sasha/.cache/huggingface/datasets/squad_v2/squad_v2/2.0.0/09187c73c1b837c95d9a249cd97c2c3f1cebada06efe667b4427714b27639b1d)

# %%
data_head = data.take(10000)
df = pd.DataFrame(data_head)

# %%
df = pd.json_normalize(data)

# %%
df.head()
# Out:
#                          id    title  \
# 0  56be85543aeaaa14008c9063  Beyoncé
# 1  56be85543aeaaa14008c9065  Beyoncé
# 2  56be85543aeaaa14008c9066  Beyoncé
# 3  56bf6b0f3aeaaa14008c9601  Beyoncé
# 4  56bf6b0f3aeaaa14008c9602  Beyoncé
#
#                                              context  \
# 0  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 2  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 3  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 4  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
#
#                                             question           answers.text  \
# 0           When did Beyonce start becoming popular?    [in the late 1990s]
# 1  What areas did Beyonce compete in when she was...  [singing and dancing]
# 2  When did Beyonce leave Destiny's Child and bec...                 [2003]
# 3      In what city and state did Beyonce  grow up?        [Houston, Texas]
# ...

# %%
def dedup_oldschool(texts):
    dict_count = {}
    count=0
    total=0
    for t in texts.tolist():
        if len(t) > 0:
            count+=1
            try:
                dict_count[str(t)] += 1
                print("Duplicate sentence %s at index %d " % (t, texts.index[count]))
                total +=1
            except KeyError:
                dict_count[str(t)] = 1
        else:
            continue
    print("Total number of duplicates is: %r out of %u" % (total, texts.shape[0]))

# %%
# %time
dedup_oldschool(df["question"])
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.01 µs
# Duplicate sentence When did Beyonce have her first child? at index 256
# Duplicate sentence What year did Chopin leave Warsaw? at index 921
# Duplicate sentence In what year did Chopin become a French citizen? at index 983
# Duplicate sentence What was the name of Liszt's mistress? at index 1065
# Duplicate sentence Who orchestrated Chopiniana? at index 1231
# Duplicate sentence Where was Chopin's last public performance? at index 1259
# Duplicate sentence Where was Chopin's funeral held? at index 1289
# Duplicate sentence How long was Chopin's funeral delayed? at index 1290
# Duplicate sentence Who paid for Chopin's funeral? at index 1308
# Duplicate sentence Who was Alexander Scriabin's teacher? at index 1406
# Duplicate sentence What was the originally-planned launch year for Twilight Princess? at index 2280
# Duplicate sentence Which airport was shut down? at index 3000
# ...
